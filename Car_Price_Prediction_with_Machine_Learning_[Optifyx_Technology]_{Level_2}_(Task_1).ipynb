# %% [markdown]
# ## Importing Libraries and Dataset for Analyzing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')

# %%
car=pd.read_csv('/content/sample_data/car data.csv')

# %%
car.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
car.shape
# Out:
# (301, 9)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %% [markdown]
# ##### Creating backup copy

# %%
backup=car.copy()

# %% [markdown]
# #### Resetting the index of the final cleaned data

# %%
car=car.reset_index(drop=True)

# %% [markdown]
# ## Cleaned Data and make Data Visualization of given data using Matplotlib or Seaborn Library

# %%
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
plt.figure(figsize=(8, 6))
plt.hist(car['Year'], bins=10, edgecolor='black')  # Adjust bins as needed
plt.title('Distribution of Car Year')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.show()

# %%
fuel_type_avg_price = car.groupby('Fuel_Type')['Selling_Price'].mean()
plt.figure(figsize=(8, 6))
fuel_type_avg_price.plot(kind='bar', color='skyblue')
plt.title('Average Selling Price by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Average Selling Price')
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()

# %%
import seaborn as sns

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='Car_Name',y='Selling_Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# <ipython-input-30-8f526ceaf642>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming the column name is actually 'Year' and not 'year'
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='Year',y='Present_Price',data=car)  # Changed 'year' to 'Year'
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# <ipython-input-39-e384333af3dc>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')

# %%
# Assuming 'car' is your DataFrame
sns.scatterplot(x='Selling_Price', y='Present_Price', data=car)
plt.title('Scatter Plot of Selling Price vs. Present Price')
plt.xlabel('Selling Price')
plt.ylabel('Present Price')
plt.show()

# %% [markdown]
# ### Checking relationship of Year with Price

# %% [markdown]
# ** Checking relationship of kms_driven with Price **

# %%
sns.relplot(x='Car_Name',y='Selling_Price',data=car,height=7,aspect=1.5)

# %% [markdown]
# ** Checking relationship of Fuel Type with Price **

# %%
plt.subplots(figsize=(14,7))
sns.boxplot(x='Fuel_Type',y='Present_Price',data=car)
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Present_Price'>

# %% [markdown]
# ** Relationship of Price with FuelType, Year and Company mixed **

# %%
ax=sns.relplot(x='Car_Name',y='Present_Price',data=car,hue='Fuel_Type',size='Year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %% [markdown]
# ### Extracting Training Data

# %%
X=car[['Car_Name','Year','Selling_Price','Present_Price','Fuel_Type']]
y=car['Car_Name']

# %%
X
# Out:
#     Car_Name  Year  Selling_Price  Present_Price Fuel_Type
# 0       ritz  2014           3.35           5.59    Petrol
# 1        sx4  2013           4.75           9.54    Diesel
# 2       ciaz  2017           7.25           9.85    Petrol
# 3    wagon r  2011           2.85           4.15    Petrol
# 4      swift  2014           4.60           6.87    Diesel
# ..       ...   ...            ...            ...       ...
# 296     city  2016           9.50          11.60    Diesel
# 297     brio  2015           4.00           5.90    Petrol
# 298     city  2009           3.35          11.00    Petrol
# 299     city  2017          11.50          12.50    Diesel
# 300     brio  2016           5.30           5.90    Petrol
#
# [301 rows x 5 columns]

# %% [markdown]
# ### Applying Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %% [markdown]
# #### Creating an OneHotEncoder object to contain all the possible categories

# %%
ohe=OneHotEncoder()
ohe.fit(X[['Car_Name','Year','Fuel_Type']])
# Out:
# OneHotEncoder()

# %% [markdown]
# #### Creating a column transformer to transform categorical columns

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Car_Name','Year','Fuel_Type']),
                                    remainder='passthrough')

# %% [markdown]
# #### Linear Regression Model

# %%
lr=LinearRegression()

# %% [markdown]
# #### Making a pipeline

# %%
pipe=make_pipeline(column_trans,lr)

# %% [markdown]
# #### Fitting the  model

# %%
y_pred=pipe.predict(X_test)

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.steps[0][1].transformers[0][1].categories[0]
# Out:
# array(['800', 'Activa 3g', 'Activa 4g', 'Bajaj  ct 100',
#        'Bajaj Avenger 150', 'Bajaj Avenger 150 street',
#        'Bajaj Avenger 220', 'Bajaj Avenger 220 dtsi',
#        'Bajaj Avenger Street 220', 'Bajaj Discover 100',
#        'Bajaj Discover 125', 'Bajaj Dominar 400', 'Bajaj Pulsar  NS 200',
#        'Bajaj Pulsar 135 LS', 'Bajaj Pulsar 150', 'Bajaj Pulsar 220 F',
#        'Bajaj Pulsar NS 200', 'Bajaj Pulsar RS200', 'Hero  CBZ Xtreme',
#        'Hero  Ignitor Disc', 'Hero Extreme', 'Hero Glamour',
#        'Hero Honda CBZ extreme', 'Hero Honda Passion Pro', 'Hero Hunk',
#        'Hero Passion Pro', 'Hero Passion X pro', 'Hero Splender Plus',
#        'Hero Splender iSmart', 'Hero Super Splendor', 'Honda Activa 125',
#        'Honda Activa 4G', 'Honda CB Hornet 160R', 'Honda CB Shine',
#        'Honda CB Trigger', 'Honda CB Unicorn', 'Honda CB twister',
#        'Honda CBR 150', 'Honda Dream Yuga ', 'Honda Karizma',
# ...
